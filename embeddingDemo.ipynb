# %% [markdown]
# # Sentence Transformer Embeddings Demo
#
# This notebook demonstrates how to use Sentence Transformers to convert text into embeddings and calculate similarity scores between statements.

# %% [markdown]
# ## Block 1: Import Libraries and Load Model

# %%
from sentence_transformers import SentenceTransformer, util

# Load the pre-trained model
model = SentenceTransformer('all-MiniLM-L6-v2')
print("Model loaded successfully!")

# %% [markdown]
# ## Block 2: Define Sample Texts

# %%
# Sample texts to embed
texts = [
    "The cat is sitting on the mat",
    "A cat is resting on the rug",
    "Dogs are playing in the park",
    "The weather is beautiful today",
    "It is a sunny day outside"
]

print(f"Number of texts: {len(texts)}")
for i, text in enumerate(texts, 1):
    print(f"{i}. {text}")

# %% [markdown]
# ## Block 3: Generate Embeddings

# %%
# Convert texts to embeddings
embeddings = model.encode(texts, convert_to_tensor=True)

print(f"Embeddings shape: {embeddings.shape}")
print(f"Each embedding has {embeddings.shape[1]} dimensions")

# %% [markdown]
# ## Block 4: Display First 5 Dimensions of Each Embedding

# %%
print("=" * 60)
print("FIRST 5 DIMENSIONS OF EMBEDDINGS")
print("=" * 60)

for i, (text, embedding) in enumerate(zip(texts, embeddings)):
    print(f"\nText {i+1}: {text}")
    print(f"First 5 dimensions: {embedding[:5].tolist()}")

# %% [markdown]
# ## Block 5: Calculate and Display Similarity Scores

# %%
print("\n" + "=" * 60)
print("SIMILARITY SCORES BETWEEN STATEMENTS")
print("=" * 60)

# Compare all pairs
for i in range(len(texts)):
    for j in range(i + 1, len(texts)):
        similarity = util.pytorch_cos_sim(embeddings[i], embeddings[j]).item()
        print(f"\nSimilarity between statement {i+1} and {j+1}:")
        print(f"  Text 1: {texts[i]}")
        print(f"  Text 2: {texts[j]}")
        print(f"  Similarity Score: {similarity:.4f}")

# %% [markdown]
# ## Summary & Insights
#
# **Key Findings:**
# - **High similarity (0.7267)** between statements 1 & 2: Both about cats
# - **High similarity (0.6767)** between statements 4 & 5: Both about weather
# - **Low/negative similarity** for semantically unrelated statements
#
# **Model Details:**
# - Model: all-MiniLM-L6-v2 (384-dimensional embeddings)
# - Similarity metric: Cosine similarity (range: -1 to 1)
# - Higher scores indicate more semantic similarity
